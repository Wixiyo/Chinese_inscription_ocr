# %%
# !pip install mmcv-full --user
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
# 安装 mmdet
# !pip install mmdet -i https://pypi.tuna.tsinghua.edu.cn/simple --user

# 安装其它工具包
# !pip install tqdm matplotlib numpy opencv-python -i https://pypi.tuna.tsinghua.edu.cn/simple --user
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
# 从 github 上下载最新的 mmocr 源代码
#!git clone https://github.com/open-mmlab/mmocr.git

# %%
# 进入 mmocr 主目录
import os
os.chdir('../')

# %%
# !pip install -r requirements.txt --user
# !pip install -v -e . --user
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Using pip 21.1.3 from /environment/miniconda3/lib/python3.7/site-packages/pip (python 3.7)
# User install by explicit request
# Created temporary directory: /tmp/pip-ephem-wheel-cache-97eln_rp
# Created temporary directory: /tmp/pip-req-tracker-nex6iigp
# Initialized build tracking at /tmp/pip-req-tracker-nex6iigp
# Created build tracker: /tmp/pip-req-tracker-nex6iigp
# Entered build tracker: /tmp/pip-req-tracker-nex6iigp
# Created temporary directory: /tmp/pip-install-fr9m74fd
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Obtaining file:///home/featurize/work/mmocr
#   Added file:///home/featurize/work/mmocr to build tracker '/tmp/pip-req-tracker-nex6iigp'
#     Running setup.py (path:/home/featurize/work/mmocr/setup.py) egg_info for package from file:///home/featurize/work/mmocr
#     Created temporary directory: /tmp/pip-pip-egg-info-50lzwe_b
#     Running command python setup.py egg_info
# ...

# %%
# 导入工具包
import torch, torchvision

import mmcv
from mmcv.ops import get_compiling_cuda_version, get_compiler_version

import mmdet

import mmocr
from mmocr.utils.ocr import MMOCR
mmocr = MMOCR(det=None, recog='SAR', device='cpu')
print('mmocr载入成功！')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_20443/1051809928.py in <module>
#       9 import mmocr
#      10 from mmocr.utils.ocr import MMOCR
# ---> 11 mmocr = MMOCR(det=None, recog='SAR', device='cpu')
#      12 print('mmocr载入成功！')
#
# ~/work/mmocr/mmocr/utils/ocr.py in __init__(self, det, det_config, det_ckpt, recog, recog_config, recog_ckpt, kie, kie_config, kie_ckpt, config_dir, device, **kwargs)
#     399
#     400             self.recog_model = init_detector(
# --> 401                 recog_config, recog_ckpt, device=self.device)
#     402             self.recog_model = revert_sync_batchnorm(self.recog_model)
#     403
#
# ~/work/mmocr/mmocr/apis/inference.py in init_detector(config, checkpoint, device, cfg_options)
#      32     """
#      33     if isinstance(config, str):
# ---> 34         config = mmcv.Config.fromfile(config)
# ...

# %%
import os
print(os.getcwd())
# Out:
# /home/featurize/work/mmocr
